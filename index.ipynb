# %% [markdown]
# # Join Statements - Lab
#
# ## Introduction
#
# In this lab, you'll practice your knowledge on Join statements.
#
# ## Objectives
#
# You will be able to:
# - Write queries that make use of various types of Joins
# - Join tables using foreign keys

# %% [markdown]
# ## CRM Schema
#
# In almost all cases, rather then just working with a single table we will typically need data from multiple tables.
# Doing this requires the use of **joins ** using shared columns from the two tables.
#
# In this lab, we'll use the same Customer Relationship Management (CRM) database we used in our lecture before!
# <img src='Database-Schema.png' width=550>

# %% [markdown]
# ## Connecting to the Database
# Import the necessary packages and connect to the database **data.sqlite**.

# %%
#Your code here
import sqlite3
conn = sqlite3.connect('data.sqlite')
cur = conn.cursor()

# %% [markdown]
# ## Display the names of all the employees in Boston.

# %%
#Your code here
cur.execute('''SELECT firstName, lastName FROM employees join offices 
            using(officeCode) WHERE city ='Boston'; ''').fetchall()
# Out:
# [('Julie', 'Firrelli'), ('Steve', 'Patterson')]

# %% [markdown]
# ## Do any offices have no employees?

# %%
#Your code here
cur.execute('''SELECT city, count(*) FROM offices
            left join employees
            using(officeCode)
            group by 1; ''').fetchall()
# Out:
# [('Boston', 2),
#  ('London', 2),
#  ('NYC', 2),
#  ('Paris', 5),
#  ('San Francisco', 6),
#  ('Sydney', 4),
#  ('Tokyo', 2)]

# %%
# All offices have employees, which makes sense.

# %% [markdown]
# ## Write 3 Questions of your own and answer them

# %%
# Answers will vary

# %%
# Your code here
# How many customers are there
cur.execute('''SELECT count(*) FROM customers''').fetchall()
# Out:
# [(122,)]

# %%
# Your code here
# How much have customers paid

cur.execute('''SELECT customers.customerName, payments.amount 
               FROM customers, payments''').fetchall()
# Out:
# [('Atelier graphique', '6066.78'),
#  ('Atelier graphique', '14571.44'),
#  ('Atelier graphique', '1676.14'),
#  ('Atelier graphique', '14191.12'),
#  ('Atelier graphique', '32641.98'),
#  ('Atelier graphique', '33347.88'),
#  ('Atelier graphique', '45864.03'),
#  ('Atelier graphique', '82261.22'),
#  ('Atelier graphique', '7565.08'),
#  ('Atelier graphique', '44894.74'),
#  ('Atelier graphique', '19501.82'),
#  ('Atelier graphique', '47924.19'),
#  ('Atelier graphique', '49523.67'),
#  ('Atelier graphique', '50218.95'),
#  ('Atelier graphique', '1491.38'),
#  ('Atelier graphique', '17876.32'),
#  ('Atelier graphique', '34638.14'),
#  ('Atelier graphique', '101244.59'),
#  ('Atelier graphique', '85410.87'),
#  ('Atelier graphique', '11044.30'),
#  ('Atelier graphique', '83598.04'),
#  ('Atelier graphique', '47142.70'),
#  ('Atelier graphique', '55639.66'),
#  ('Atelier graphique', '111654.40'),
#  ('Atelier graphique', '43369.30'),
#  ('Atelier graphique', '45084.38'),
# ...

# %%
# Your code here
cur.execute('''SELECT customers.customerName, payments.paymentDate 
               FROM customers, payments''').fetchall()
# Out:
# [('Atelier graphique', '2004-10-19'),
#  ('Atelier graphique', '2003-06-05'),
#  ('Atelier graphique', '2004-12-18'),
#  ('Atelier graphique', '2004-12-17'),
#  ('Atelier graphique', '2003-06-06'),
#  ('Atelier graphique', '2004-08-20'),
#  ('Atelier graphique', '2003-05-20'),
#  ('Atelier graphique', '2004-12-15'),
#  ('Atelier graphique', '2003-05-31'),
#  ('Atelier graphique', '2004-03-10'),
#  ('Atelier graphique', '2004-11-14'),
#  ('Atelier graphique', '2004-08-08'),
#  ('Atelier graphique', '2005-02-22'),
#  ('Atelier graphique', '2003-02-16'),
#  ('Atelier graphique', '2003-10-28'),
#  ('Atelier graphique', '2004-11-04'),
#  ('Atelier graphique', '2004-11-28'),
#  ('Atelier graphique', '2005-03-05'),
#  ('Atelier graphique', '2004-08-28'),
#  ('Atelier graphique', '2003-04-11'),
#  ('Atelier graphique', '2005-04-16'),
#  ('Atelier graphique', '2004-12-27'),
#  ('Atelier graphique', '2004-11-02'),
#  ('Atelier graphique', '2003-08-15'),
#  ('Atelier graphique', '2004-03-26'),
# ...

# %% [markdown]
# ## Level Up: Display the names of each product each employee has sold.

# %%
import pandas as pd
# Your code here
cur.execute("""select firstName, lastName,
                      productName
                      from employees e
                      join
                      customers c
                      on e.employeeNumber = c.salesRepEmployeeNumber
                      join orders o
                      using(customerNumber)
                      join orderdetails od
                      using(orderNumber)
                      join products p
                      using(productCode)""")
df = pd.DataFrame(cur.fetchall())
print(len(df))
df.head()
# Out:
# 2996
#         0         1                                            2
# 0  Leslie  Jennings                               1958 Setra Bus
# 1  Leslie  Jennings                       1940 Ford Pickup Truck
# 2  Leslie  Jennings                      1939 Cadillac Limousine
# 3  Leslie  Jennings  1996 Peterbilt 379 Stake Bed with Outrigger
# 4  Leslie  Jennings                            1968 Ford Mustang

# %% [markdown]
# ## Level Up: Display the Number of Products each Employee Has sold

# %%
#Your code here

df.groupby([0,1]).count()
# Out:
#                       2
# 0        1
# Andy     Fixter     185
# Barry    Jones      220
# Foon Yue Tseng      142
# George   Vanauf     211
# Gerard   Hernandez  396
# Julie    Firrelli   124
# Larry    Bott       236
# Leslie   Jennings   331
#          Thompson   114
# Loui     Bondur     177
# Mami     Nishi      137
# Martin   Gerard     114
# Pamela   Castillo   272
# Peter    Marsh      185
# Steve    Patterson  152

# %% [markdown]
# ## Summary

# %% [markdown]
# Congrats! You now know how to use Join statements, along with leveraging your foreign keys knowledge!
